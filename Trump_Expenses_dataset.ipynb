# %%
import pandas as pd

# %%
df= pd.read_csv("data/propublica_trump_spending-1.csv")
df
# Out:
#             type                               source          date    amount  \
# 0            FEC  Donald J. Trump for President, Inc.  Apr 30, 2015   1380.54
# 1            FEC  Donald J. Trump for President, Inc.   May 5, 2015   9583.33
# 2            FEC  Donald J. Trump for President, Inc.  Jun 16, 2015  37993.04
# 3            FEC  Donald J. Trump for President, Inc.  Jun 16, 2015   3240.96
# 4            FEC  Donald J. Trump for President, Inc.  Jun 16, 2015   9583.33
# ...          ...                                  ...           ...       ...
# 1188  government                  Department of State     undefined   5583.13
# 1189  government                  Department of State     undefined   4853.29
# 1190  government                  Department of State     undefined  10398.33
# 1191  government                  Department of State     undefined    592.13
# 1192  government                Department of Defense  Jan 24, 2017    103.25
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193 entries, 0 to 1192
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               1193 non-null   object
#  1   source             1193 non-null   object
#  2   date               1193 non-null   object
#  3   amount             1193 non-null   float64
#  4   purpose_scrubbed   1193 non-null   object
#  5   property_scrubbed  1193 non-null   object
#  6   purpose            1182 non-null   object
#  7   property           1193 non-null   object
#  8   city               1160 non-null   object
#  9   state              1158 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 93.3+ KB
